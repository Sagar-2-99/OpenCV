# %%
import numpy as nnp
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('Earth-8-2880x1800.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = cv2.imread('wrong/path/asda.jpg)
# Out:
#   Cell In[6], line 1
#     img = cv2.imread('wrong/path/asda.jpg)
#                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1800, 2880, 3)

# %%
plt.imshow(img)

# %%
#MATPLOTLIB ---> RGB 
#OPENCV ---> BGR
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img_gray = cv2.imread('Earth-8-2880x1800.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray)

# %%
img_gray = cv2.cvtColor(img_gray, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img)

# %%
new_img = cv2.resize(img, (1000,400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(img, (0,0), img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
nnew_img = cv2.flip(img, 0) #flipping image

# %%
plt.imshow(nnew_img)

# %%
nnew_img = cv2.flip(img, 1) #flipping image along vertical axis
plt.imshow(nnew_img)

# %%
nnew_img = cv2.flip(img, -1) #flipping image
plt.imshow(nnew_img)

# %%
type(nnew_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg',nnew_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 8)) #figsize can be used to set the canvas size 
ax = fig.add_subplot(111)
ax.imshow(nnew_img)
