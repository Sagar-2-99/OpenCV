# %%
import cv2 

img = cv2.imread('Earth-8-2880x1800.jpg')
cv2.imshow('Puppy', img)

cv2.waitKey()
# Out:
# 2025-02-20 23:05:43.178 python[12116:396293] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-20 23:05:43.178 python[12116:396293] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
import cv2

img = cv2.imread('Earth-8-2880x1800.jpg')
while True:
    cv2.imshow('Puppy', img)

    if cv2.waitKey(1) & 0xFF == 27:
        break
cv2.destroyAllWindows()
# Out:
# 2025-02-20 23:11:34.064 python[12864:412524] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-20 23:11:34.064 python[12864:412524] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
#matplotlib inline

# %%
blank_img = np.zeros(shape=(512,512,3),dtype=np.int16)
blank_img.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(blank_img)

# %%
cv2.rectangle(blank_img, pt1=(384, 0), pt2=(500,150), color=(0,255,0),thickness=10)#Does't returns and directly adds it
plt.imshow(blank_img)

# %%
cv2.circle(img = blank_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(blank_img)

# %%
cv2.circle(img = blank_img, center=(400,400), radius=50, color=(255,0,0), thickness=-1)
plt.imshow(blank_img)

# %%
cv2.line(blank_img, pt1=(0,0), pt2=(512,512),color=(0, 0, 199), thickness=5)
plt.imshow(blank_img)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(blank_img, text="Hello", org=(10, 500), fontFace = font, fontScale=4, color=(255,255,255),thickness=3, lineType=cv2.LINE_AA)
plt.imshow(blank_img)

# %%
blank_img = np.zeros(shape=(512,512,3),dtype=np.int32)

# %%
plt.imshow(blank_img)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)

# %%
vertices.shape
# Out:
# (4, 2)

# %%
pts = vertices.reshape((-1,1,2))

# %%
vertices.shape
# Out:
# (4, 2)

# %%
pts.shape
# Out:
# (4, 1, 2)

# %%
cv2.polylines(blank_img, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(blank_img)
