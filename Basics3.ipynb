# %%
import cv2 as cv

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
pic = Image.open("Earth-8-2880x1800.jpg")

# %%
plt.imshow(pic)

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1800, 2880, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
plt.imshow(pic_red[:,:,2]) #Red color

# %%
plt.imshow(pic_red[:,:,0]) #Blue color

# %%
plt.imshow(pic_red[:,:,1]) #Green Color

# %%
plt.imshow(pic_red[:,:,1], cmap='gray') #Green Color

# %%
pic_red[:,:,1]=0
plt.imshow(pic_red)
